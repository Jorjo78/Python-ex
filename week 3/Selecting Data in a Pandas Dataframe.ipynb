# %% [markdown]
# # Selecting DataFrame Data

# %%
import os
# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /

# %%
import pandas as pd
file_path = '/Users/giorgiocavallo/Desktop/Python/coursera/week_3/customers-100.csv'
df = pd.read_csv(file_path, sep=';', quotechar='"', skipinitialspace=True)
df.head(2)
# Out:
#    Index      Customer Id First Name Last Name          Company  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano      Vega-Gentry
#
#                 City   Country       Phone 1           Phone 2  \
# 0       East Leonard     Chile  229.077.5154  397.884.0519x718
# 1  East Jimmychester  Djibouti    5153435776  686-620-1820x944
#
#                       Email Subscription Date                     Website
# 0  zunigavanessa@smith.info        24/08/2020  http://www.stephenson.com/
# 1           vmata@colon.com        23/04/2021       http://www.hobbs.com/

# %% [markdown]
# ## Boolean mask

# %%
mask = [False for i in range (len(df))]  # for _ in range(len(df)): This is a loop that iterates over a range from 0 to len(df) - 1. The _ is a convention used when we don’t care about the loop variable.
mask[3:7] = [True] * 4   ##this is a slice of the mask list. It selects elements starting from index 3 up to (but not including) index 7.
mask
# Out:
# [False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
df.loc[mask]
# Out:
#    Index      Customer Id First Name Last Name  \
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
# 5      6  2d08FB17EE273F4      Aimee     Downs
# 6      7  EA4d384DfDbBf77     Darren      Peck
#
#                            Company            City  \
# 3  Dominguez, Mcmillan and Donovan      Bensonview
# 4         Martin, Lang and Andrade  West Priscilla
# 5                     Steele Group   Chavezborough
# 6     Lester, Woodard and Mitchell        Lake Ana
#
#                       Country                 Phone 1                Phone 2  \
# 3          Dominican Republic  001-808-617-6467x12895                  -9892
# 4  Slovakia (Slovak Republic)  001-234-203-0635x76146  001-199-446-3860x3486
# 5      Bosnia and Herzegovina     (283)437-3886x88321           999-728-1637
# 6            Pitcairn Islands      (496)452-6181x3291   +1-247-266-0963x4995
#
#                          Email Subscription Date                      Website
# ...

# %% [markdown]
# ### Creating masks using comparison operators

# %%
mask = df.loc[:, 'First Name'].str.len() < df.loc[:, 'Last Name'].str.len()
df[mask]
# Out:
#     Index      Customer Id First Name    Last Name  \
# 2       3  6F94879bDAfE5a6        Roy        Berry
# 7       8  0e04AFde9f225dE      Brett       Mullen
# 9      10  8C2811a503C7c5a   Michelle    Gallagher
# 10     11  216E205d6eBb815       Carl    Schroeder
# 11     12  CEDec94deE6d69B      Jenna       Dodson
# 20     22  FBd0Ded4F02a742      Kiara      Houston
# 22     24  010468dAA11382c      Janet   Valenzuela
# 23     25  eC1927Ca84E033e      Shane       Wilcox
# 27     29  3B5dAAFA41AFa22   Stefanie  Fitzpatrick
# 28     30  EDA69ca7a6e96a2       Kent     Bradshaw
# 30     32  679c6c83DD872d6        Tom     Trujillo
# 37     39  dca4f1D0A0fc5c9      Bruce      Esparza
# 41     43  7E441b6B228DBcA      Wayne      Simpson
# 42     44  D3fC11A9C235Dc6       Luis        Greer
# 49     51  Aa20BDe68eAb0e9     Gerald      Hawkins
# 50     52  e898eEB1B9FE22b     Samuel     Crawford
# 52     54  c09952De6Cda8aA     Stacie      Richard
# ...

# %% [markdown]
# ### Pandas boolean operators  and/or/Not

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              99 non-null     int64
#  1   Customer Id        99 non-null     object
#  2   First Name         99 non-null     object
#  3   Last Name          99 non-null     object
#  4   Company            99 non-null     object
#  5   City               99 non-null     object
#  6   Country            99 non-null     object
#  7   Phone 1            99 non-null     object
#  8   Phone 2            99 non-null     object
#  9   Email              99 non-null     object
#  10  Subscription Date  99 non-null     object
#  11  Website            99 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 9.4+ KB

# %%
mask = (df.loc[:, 'First Name'].str.len() < 4) & (df.loc[:, 'Last Name'].str.len() > 5)

# %%
df[mask]
# Out:
#     Index      Customer Id First Name Last Name              Company  \
# 30     32  679c6c83DD872d6        Tom  Trujillo          Mcgee Group
# 66     68  a014Ec1b9FccC1E        Tom  Alvarado  Donaldson-Dougherty
#
#                  City   Country             Phone 1            Phone 2  \
# 30  Cunninghamborough   Denmark        416-338-3758      (775)890-7209
# 66   South Sophiaberg  Kiribati  (585)606-2980x2258  730-797-3594x5614
#
#                             Email Subscription Date  \
# 30           tapiagreg@beard.info        13/01/2022
# 66  nicholsonnina@montgomery.info        18/08/2020
#
#                           Website
# 30  http://www.daniels-klein.com/
# 66        http://odom-massey.com/

# %% [markdown]
# #### Creating new column

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')
