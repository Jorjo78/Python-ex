# %%
import pandas as pd
try:
    # Try to import the library
    import matplotlib.pyplot as plt
    print("matplotlib is already installed.")
except ModuleNotFoundError:
    # If the library is not installed, install it
    print("matplotlib not found. Installing...")
    # !pip install matplotlib  ## works onnly for Jupiter Notebooks
    print("matplotlib has been installed.")
# Out:
# matplotlib is already installed.

# %% [markdown]
# # Create dummy Dataframe

# %%
data = {'name': ['John', 'Mary', 'Sam', 'Sarah'],
        'height': [183, 167, 174, 160],
        'weight':[89, 56, 70, 50]}

df = pd.DataFrame(data)
df
# Out:
#     name  height  weight
# 0   John     183      89
# 1   Mary     167      56
# 2    Sam     174      70
# 3  Sarah     160      50

# %%
df.info()   ## .info() is the str() function of R
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   height  4 non-null      int64
#  2   weight  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %% [markdown]
# ## Scatter plot height vs weight

# %%
df.plot.scatter(x= 'height', y = 'weight')
# Out:
# <Axes: xlabel='height', ylabel='weight'>

# %% [markdown]
# ## Set labels and title

# %%
plt.scatter(df['height'], df['weight'])
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('Height vs Weight')


plt.tight_layout()
plt.show()

# %%
## Function to filter by height range

def filter_height(df, min_ht, max_ht):
    return df[(df['height'] >= min_ht) & (df['height'] <= max_ht)]

# %%
### Filter rows between 160 cm and 170 cm height
result = filter_height(df, 160, 170)
print(result)
# Out:
#     name  height  weight
# 1   Mary     167      56
# 3  Sarah     160      50
